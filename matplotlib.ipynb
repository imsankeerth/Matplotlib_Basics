# %%
#Matplotlib is a plotting library for the Python programming language.
#Matplotlib tries to make easy things easy and hard things possible. You can generate plots, histograms, power spectra, bar charts, errorcharts, scatterplots, etc.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,6,9)

# %%
x
# Out:
# array([0.  , 0.75, 1.5 , 2.25, 3.  , 3.75, 4.5 , 5.25, 6.  ])

# %%
y=np.linspace(3,9,9)

# %%
y
# Out:
# array([3.  , 3.75, 4.5 , 5.25, 6.  , 6.75, 7.5 , 8.25, 9.  ])

# %%
plt.plot(x,y)

# %%
#plt.legend()--When there are multiple curves in the graph,legen gives you easy identification of the curve to that respective label

# %%
plt.plot([1,2,3,4,5],[2,4,6,8,10],label='HELLO')
plt.xlabel("X_AXIS")
plt.ylabel('Y_AXIS')
plt.title("MINE")
plt.legend()

# %%
plt.bar([1,2,3,4,5],[2,4,6,8,10],label='DEMO')
plt.title("DEMO BAR GRAPH")
# Out:
# Text(0.5, 1.0, 'DEMO BAR GRAPH')

# %%
a=[9,7,5,3,8]
a1=[7,8,8,3,4]
a2=[9,7,9,9,9]

# %%
plt.plot([],[],color='#F97F51',label='a')
plt.plot([],[],color='#1B9CFC',label='a1')
plt.plot([],[],color='#F8EFBA',label='a2')
plt.stackplot(a,a1,a2,colors=['#F97F51','#1B9CFC','#F8EFBA'])
plt.legend()

# %%
#piechart

# %%
mlabels=['fb','twitter','insta']

# %%
piecolors=['#F97F51','#1B9CFC','#FD7272']

# %%
plt.pie(ads,labels=mlabels,colors=piecolors,explode=(0,0,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x134129b0>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, 'fb'),
#   Text(-0.9088626158329182, -0.6196521165471361, 'twitter'),
#   Text(0.8063571273955387, -0.7481899378489497, 'insta')])

# %%
plt.pie(ads,labels=mlabels,colors=piecolors,explode=(0,0.1,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x133492f0>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, 'fb'),
#   Text(-0.991486489999547, -0.6759841271423304, 'twitter'),
#   Text(0.8063571273955387, -0.7481899378489497, 'insta')])
